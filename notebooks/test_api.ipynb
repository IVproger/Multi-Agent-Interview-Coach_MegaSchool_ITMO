# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv('../.env')
# Out:
# True

# %%
model = ChatOpenAI(
    model="openai/gpt-4o-mini", 
    api_key=os.getenv("OPENROUTER_API_KEY"),
    base_url=os.getenv("OPENROUTER_BASE_URL"),
)

from langchain_core.messages import HumanMessage
response = model.invoke([HumanMessage(content="What is LangChain?")])
print(response.content)
# Out:
# LangChain is a framework designed to facilitate the development of applications that utilize large language models (LLMs). It provides a structure for integrating LLMs with various components, enabling developers to build complex applications that can handle a wide range of tasks, such as chatbots, question-answering systems, and content generation tools.
#
# Key features of LangChain include:
#
# 1. **Modularity**: It allows developers to combine different components, such as LLMs, document stores, and APIs, to create comprehensive solutions.
#
# 2. **Chain Management**: LangChain enables the creation of chains that define the workflow of interactions with LLMs, allowing for more structured and efficient processing of tasks.
#
# 3. **Memory Management**: The framework supports memory capabilities to maintain context over multiple interactions, improving the coherence of conversations and responses.
#
# 4. **Integration with Data Sources**: LangChain can connect with various data sources, such as databases and APIs, to enrich the interactions and outputs generated by LLMs.
#
# 5. **Prompt Management**: It offers tools for managing and optimizing prompts sent to LLMs, which is crucial for obtaining high-quality outputs.
#
# Overall, LangChain aims to simplify the development of applications that leverage the capabilities of language models, making it easier for developers to create powerful and interactive user experiences.
